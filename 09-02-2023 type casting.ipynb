# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
d=pd.read_csv('Car_sales.csv')

# %%
d.sample(20)
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 78       Lincoln       Navigator              22.925                  NaN
# 65      Infiniti             I30              23.713               19.690
# 43         Dodge          Dakota             111.313               11.260
# 127         Saab           5-Sep               9.191                  NaN
# 23     Chevrolet          Camaro              26.402               13.025
# 104       Nissan           Quest              27.308               15.380
# 74         Lexus           LX470               9.126                  NaN
# 139       Toyota          Celica              33.269               15.445
# 33      Chrysler  Town & Country              53.480               19.540
# 128         Saab           3-Sep              12.115                  NaN
# 54          Ford      Expedition             125.338               23.575
# 155        Volvo             C70               3.493                  NaN
# ...

# %% [markdown]
# # drop Na

# %%
d.dropna(inplace=True)
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %% [markdown]
# #### Checking The contents in latest launch column

# %%
# unique fuction use as to list down unique values in a column

# %%
d.Latest_Launch.unique()
# Out:
# array(['2/2/2012', '6/3/2011', '3/10/2011', '10/8/2011', '8/9/2011',
#        '2/27/2012', '1/29/2012', '4/4/2011', '11/2/2011', '9/3/2011',
#        '3/23/2012', '7/23/2011', '2/23/2012', '11/27/2011', '9/28/2011',
#        '8/17/2011', '3/19/2012', '5/24/2011', '12/22/2011', '10/23/2011',
#        '5/12/2012', '9/11/2011', '4/13/2012', '1/16/2012', '11/17/2011',
#        '6/6/2012', '10/6/2011', '5/8/2012', '12/12/2011', '7/1/2012',
#        '10/31/2011', '8/7/2011', '3/6/2012', '1/6/2012', '7/26/2012',
#        '11/25/2011', '9/1/2011', '3/31/2012', '1/31/2012', '8/20/2012',
#        '12/20/2011', '9/26/2011', '4/25/2012', '2/25/2012', '9/14/2012',
#        '1/14/2012', '8/16/2012', '10/21/2011', '5/20/2012', '3/21/2012',
#        '10/9/2012', '2/8/2012', '9/10/2012', '11/15/2011', '6/14/2012',
#        '4/15/2012', '3/4/2012', '10/5/2012', '12/10/2011', '7/9/2012',
#        '5/10/2012', '3/29/2012', '8/3/2012', '6/4/2012', '4/23/2012',
# ...

# %% [markdown]
# #### Change its dtype into date time

# %%
d['Latest_Launch']=pd.to_datetime(d.Latest_Launch)

# %%
d.head(20)
# Out:
#    Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 0         Acura      Integra              16.919               16.360
# 1         Acura           TL              39.384               19.875
# 3         Acura           RL               8.588               29.725
# 4          Audi           A4              20.397               22.255
# 5          Audi           A6              18.780               23.555
# 6          Audi           A8               1.380               39.000
# 8           BMW         328i               9.231               28.675
# 9           BMW         528i              17.527               36.125
# 10        Buick      Century              91.561               12.475
# 11        Buick        Regal              39.350               13.740
# 12        Buick  Park Avenue              27.851               20.190
# 13        Buick      LeSabre              83.257               13.360
# ...

# %% [markdown]
# #### Check the dtype in it

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %% [markdown]
# ## we can see that it have changed to date time 64[ns] format.

# %%
d['Year']=pd.DatetimeIndex(d.Latest_Launch).year

# %%
d.sample(10)
# Out:
#     Manufacturer       Model  Sales_in_thousands  __year_resale_value  \
# 92    Mercedes-B     C-Class              18.392               26.050
# 9            BMW        528i              17.527               36.125
# 24     Chevrolet    Corvette              17.947               36.225
# 54          Ford  Expedition             125.338               23.575
# 122      Pontiac  Bonneville              35.945               13.225
# 1          Acura          TL              39.384               19.875
# 59         Honda        CR-V              73.203               17.710
# 48          Ford     Contour              35.068                8.835
# 21     Chevrolet      Lumina              24.629               10.310
# 119      Pontiac    Grand Am             131.097               10.290
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 92     Passenger              31.750          2.3       185.0      105.9
# ...

# %%
d['month']=pd.DatetimeIndex(d.Latest_Launch).month

# %%
d.sample(20)
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 77       Lincoln        Town car              48.911               21.725
# 126      Porsche  Carrera Cabrio               1.866               67.550
# 148   Volkswagen          Cabrio               9.569               16.575
# 69          Jeep  Grand Cherokee             157.040               18.810
# 14      Cadillac         DeVille              63.729               22.525
# 95    Mercedes-B        SL-Class               3.311               58.600
# 86       Mercury        Mystique              14.351                8.800
# 76       Lincoln     Continental              13.798               20.525
# 140       Toyota          Tacoma              84.087                9.575
# 46          Ford          Escort              70.227                7.425
# 61         Honda         Odyssey              76.029               19.490
# 146   Volkswagen           Jetta              83.721               13.240
# ...

# %%
d['day']=pd.DatetimeIndex(d.Latest_Launch).day

# %%
d.sample(35)
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 81    Mitsubishi          Galant              55.616               10.595
# 89       Mercury   Grand Marquis              81.174               14.875
# 65      Infiniti             I30              23.713               19.690
# 30      Chrysler        Concorde              31.148               13.725
# 77       Lincoln        Town car              48.911               21.725
# 140       Toyota          Tacoma              84.087                9.575
# 24     Chevrolet        Corvette              17.947               36.225
# 69          Jeep  Grand Cherokee             157.040               18.810
# 57         Honda           Civic             199.685                9.850
# 80    Mitsubishi         Eclipse              42.541               10.395
# 40         Dodge      Ram Pickup             227.061               15.060
# 120      Pontiac        Firebird              19.911               17.805
# ...

# %% [markdown]
# ## Converting Numerical into catagorical Column
# #### Lets Convert The month numbers into thair corresponding names

# %%
d.month.replace({
    1:'Jan',
    2:"Feb",
    3:'Mar',
    4:'Apr',
    5:'May',
    6:'Jun',
    7:'Jul',
    8:'Aug',
    9:'Sep',
    10:'Oct',
    11:'Nov',
    12:'Dec,'
},inplace=True
)

# %%
d.sample(10)
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 16      Cadillac       Eldorado               6.536               25.725
# 11         Buick          Regal              39.350               13.740
# 82    Mitsubishi       Diamante               5.711               16.575
# 113   Oldsmobile     Silhouette              24.361               15.240
# 103       Nissan         Maxima              79.853               15.125
# 47          Ford        Mustang             113.369               12.760
# 28      Chrysler  Sebring Coupe               7.854               12.360
# 24     Chevrolet       Corvette              17.947               36.225
# 85    Mitsubishi  Montero Sport              39.348               13.880
# 6           Audi             A8               1.380               39.000
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 16     Passenger              39.665          4.6       275.0      108.0
# ...

# %% [markdown]
# # Label encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l=LabelEncoder()

# %%
d['']
